# %%
import numpy as np
import pandas as pd

# %%
file_path= "C:\\Users\\admin\\Documents\\Data set.xlsx"
df=pd.read_excel(file_path)
df.head(20)
# Out:
#          Date  Coal_RB_4800_FOB_London_Close_USD  \
# 0  2020-04-02                              41.00
# 1  2020-04-03                              40.34
# 2  2020-04-06                              40.34
# 3  2020-04-07                              40.34
# 4  2020-04-08                              40.34
# 5  2020-04-09                              33.82
# 6  2020-04-10                                NaN
# 7  2020-04-13                                NaN
# 8  2020-04-14                              33.82
# 9  2020-04-15                              33.82
# 10 2020-04-16                              33.82
# 11 2020-04-17                              31.49
# 12 2020-04-20                              31.49
# 13 2020-04-21                              31.49
# 14 2020-04-22                              31.49
# 15 2020-04-23                              31.49
# 16 2020-04-24                              26.75
# 17 2020-04-27                              26.75
# ...

# %%
df.describe()
# Out:
#                                 Date  Coal_RB_4800_FOB_London_Close_USD  \
# count                           1107                        1068.000000
# mean   2022-05-16 14:22:26.341463296                          87.953184
# min              2020-04-02 00:00:00                          26.750000
# 25%              2021-04-24 12:00:00                          50.370000
# 50%              2022-05-17 00:00:00                          76.190000
# 75%              2023-06-07 12:00:00                         104.180000
# max              2024-06-28 00:00:00                         301.090000
# std                              NaN                          47.303473
#
#        Coal_RB_5500_FOB_London_Close_USD  Coal_RB_5700_FOB_London_Close_USD  \
# count                        1068.000000                        1068.000000
# mean                          113.353155                         134.971807
# min                            34.560000                          44.690000
# ...

# %%
df.isnull().sum()/df.count()*100
# Out:
# Date                                    0.000000
# Coal_RB_4800_FOB_London_Close_USD       3.651685
# Coal_RB_5500_FOB_London_Close_USD       3.651685
# Coal_RB_5700_FOB_London_Close_USD       3.651685
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD    2.121771
# Coal_India_5500_CFR_London_Close_USD    3.651685
# Price_WTI                               0.727934
# Price_Brent_Oil                         1.003650
# Price_Dubai_Brent_Oil                   3.748828
# Price_ExxonMobil                        3.748828
# Price_Shenhua                           6.238004
# Price_All_Share                         4.631380
# Price_Mining                            4.631380
# Price_LNG_Japan_Korea_Marker_PLATTS     3.846154
# Price_ZAR_USD                           0.000000
# Price_Natural_Gas                       0.727934
# Price_ICE                               3.748828
# Price_Dutch_TTF                         2.881041
# Price_Indian_en_exg_rate                5.730659
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Date                                     0
# Coal_RB_4800_FOB_London_Close_USD       39
# Coal_RB_5500_FOB_London_Close_USD       39
# Coal_RB_5700_FOB_London_Close_USD       39
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD    23
# Coal_India_5500_CFR_London_Close_USD    39
# Price_WTI                                8
# Price_Brent_Oil                         11
# Price_Dubai_Brent_Oil                   40
# Price_ExxonMobil                        40
# Price_Shenhua                           65
# Price_All_Share                         49
# Price_Mining                            49
# Price_LNG_Japan_Korea_Marker_PLATTS     41
# Price_ZAR_USD                            0
# Price_Natural_Gas                        8
# Price_ICE                               40
# Price_Dutch_TTF                         31
# Price_Indian_en_exg_rate                60
# dtype: int64

# %%
df.dropna(inplace = True)
df
# Out:
#            Date  Coal_RB_4800_FOB_London_Close_USD  \
# 1    2020-04-03                              40.34
# 3    2020-04-07                              40.34
# 4    2020-04-08                              40.34
# 5    2020-04-09                              33.82
# 9    2020-04-15                              33.82
# ...         ...                                ...
# 1102 2024-06-24                              73.30
# 1103 2024-06-25                              73.30
# 1104 2024-06-26                              73.30
# 1105 2024-06-27                              73.30
# 1106 2024-06-28                              71.38
#
#       Coal_RB_5500_FOB_London_Close_USD  Coal_RB_5700_FOB_London_Close_USD  \
# 1                                 52.36                              63.10
# 3                                 52.36                              63.10
# 4                                 52.36                              63.10
# ...

# %%
df.isnull().sum()
# Out:
# Date                                    0
# Coal_RB_4800_FOB_London_Close_USD       0
# Coal_RB_5500_FOB_London_Close_USD       0
# Coal_RB_5700_FOB_London_Close_USD       0
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD    0
# Coal_India_5500_CFR_London_Close_USD    0
# Price_WTI                               0
# Price_Brent_Oil                         0
# Price_Dubai_Brent_Oil                   0
# Price_ExxonMobil                        0
# Price_Shenhua                           0
# Price_All_Share                         0
# Price_Mining                            0
# Price_LNG_Japan_Korea_Marker_PLATTS     0
# Price_ZAR_USD                           0
# Price_Natural_Gas                       0
# Price_ICE                               0
# Price_Dutch_TTF                         0
# Price_Indian_en_exg_rate                0
# dtype: int64

# %%
df.drop("Date",inplace =True,axis=1)
df
# Out:
#       Coal_RB_4800_FOB_London_Close_USD  Coal_RB_5500_FOB_London_Close_USD  \
# 1                                 40.34                              52.36
# 3                                 40.34                              52.36
# 4                                 40.34                              52.36
# 5                                 33.82                              43.58
# 9                                 33.82                              43.58
# ...                                 ...                                ...
# 1102                              73.30                              94.56
# 1103                              73.30                              94.56
# 1104                              73.30                              94.56
# 1105                              73.30                              94.56
# 1106                              71.38                              92.08
#
# ...

# %%
df.var()
# Out:
# Coal_RB_4800_FOB_London_Close_USD       2.294182e+03
# Coal_RB_5500_FOB_London_Close_USD       4.074232e+03
# Coal_RB_5700_FOB_London_Close_USD       6.130739e+03
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD    7.073207e+03
# Coal_India_5500_CFR_London_Close_USD    3.236738e+03
# Price_WTI                               4.221615e+02
# Price_Brent_Oil                         4.274815e+02
# Price_Dubai_Brent_Oil                   4.170168e+02
# Price_ExxonMobil                        7.694542e+02
# Price_Shenhua                           3.735906e+01
# Price_All_Share                         6.253875e+07
# Price_Mining                            4.912183e+07
# Price_LNG_Japan_Korea_Marker_PLATTS     1.618984e+02
# Price_ZAR_USD                           3.645467e-05
# Price_Natural_Gas                       3.674520e+00
# Price_ICE                               1.862010e+02
# Price_Dutch_TTF                         2.915575e+03
# Price_Indian_en_exg_rate                2.905038e+03
# ...

# %%
df.head(10)
# Out:
#     Coal_RB_4800_FOB_London_Close_USD  Coal_RB_5500_FOB_London_Close_USD  \
# 1                               40.34                              52.36
# 3                               40.34                              52.36
# 4                               40.34                              52.36
# 5                               33.82                              43.58
# 9                               33.82                              43.58
# 10                              33.82                              43.58
# 11                              31.49                              38.44
# 12                              31.49                              38.44
# 13                              31.49                              38.44
# 14                              31.49                              38.44
#
#     Coal_RB_5700_FOB_London_Close_USD  Coal_RB_6000_FOB_CurrentWeek_Avg_USD  \
# 1                               63.10                                 70.57
# ...

# %%
df["Price_Indian_en_exg_rate"].mean()
# Out:
# np.float64(140.7919806243272)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.mean()          #Mean of data set
# Out:
# Coal_RB_4800_FOB_London_Close_USD          87.918945
# Coal_RB_5500_FOB_London_Close_USD         113.359236
# Coal_RB_5700_FOB_London_Close_USD         135.002551
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD      144.218665
# Coal_India_5500_CFR_London_Close_USD      123.652853
# Price_WTI                                  72.099602
# Price_Brent_Oil                            76.058041
# Price_Dubai_Brent_Oil                      74.630893
# Price_ExxonMobil                           80.660850
# Price_Shenhua                              21.210291
# Price_All_Share                         68663.591572
# Price_Mining                            52983.184790
# Price_LNG_Japan_Korea_Marker_PLATTS        17.620604
# Price_ZAR_USD                               0.059924
# Price_Natural_Gas                           3.695940
# Price_ICE                                 112.574973
# Price_Dutch_TTF                            57.631833
# Price_Indian_en_exg_rate                  140.791981
# ...

# %% [markdown]
# **The number that appears most often in a set of data is mode**

# %%
df.mode()
# Out:
#      Coal_RB_4800_FOB_London_Close_USD  Coal_RB_5500_FOB_London_Close_USD  \
# 0                                33.86                              47.56
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 924                                NaN                                NaN
# 925                                NaN                                NaN
# 926                                NaN                                NaN
# 927                                NaN                                NaN
# 928                                NaN                                NaN
#
#      Coal_RB_5700_FOB_London_Close_USD  Coal_RB_6000_FOB_CurrentWeek_Avg_USD  \
# ...

# %%
df["Coal_RB_4800_FOB_London_Close_USD"].mode()
# Out:
# 0    33.86
# Name: Coal_RB_4800_FOB_London_Close_USD, dtype: float64

# %%
df.median()
# Out:
# Coal_RB_4800_FOB_London_Close_USD          76.19000
# Coal_RB_5500_FOB_London_Close_USD          95.80000
# Coal_RB_5700_FOB_London_Close_USD         108.91000
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD      115.27000
# Coal_India_5500_CFR_London_Close_USD      111.20000
# Price_WTI                                  75.37000
# Price_Brent_Oil                            79.67000
# Price_Dubai_Brent_Oil                      78.49000
# Price_ExxonMobil                           86.12000
# Price_Shenhua                              22.30000
# Price_All_Share                         69921.37000
# Price_Mining                            53269.08000
# Price_LNG_Japan_Korea_Marker_PLATTS        12.93500
# Price_ZAR_USD                               0.05876
# Price_Natural_Gas                           2.85900
# Price_ICE                                 111.72000
# Price_Dutch_TTF                            35.65500
# Price_Indian_en_exg_rate                  140.62000
# dtype: float64

# %% [markdown]
# **Range is the difference between max value and min value**

# %%
range_all = df.max() - df.min()           #Range of individual columns
print(range_all)
# Out:
# Coal_RB_4800_FOB_London_Close_USD         274.34000
# Coal_RB_5500_FOB_London_Close_USD         325.68000
# Coal_RB_5700_FOB_London_Close_USD         367.66000
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD      383.69000
# Coal_India_5500_CFR_London_Close_USD      271.08000
# Price_WTI                                 161.33000
# Price_Brent_Oil                           108.65000
# Price_Dubai_Brent_Oil                     103.46000
# Price_ExxonMobil                           90.63000
# Price_Shenhua                              28.24000
# Price_All_Share                         36192.66000
# Price_Mining                            39870.14000
# Price_LNG_Japan_Korea_Marker_PLATTS        67.95500
# Price_ZAR_USD                               0.02388
# Price_Natural_Gas                           8.15200
# Price_ICE                                  58.44000
# Price_Dutch_TTF                           335.68500
# Price_Indian_en_exg_rate                  250.23000
# dtype: float64

# %% [markdown]
# **Standard deviation measures the spread of data from the mean**

# %%
df.std()            #Standard deviation of individual columns
# Out:
# Coal_RB_4800_FOB_London_Close_USD         47.897621
# Coal_RB_5500_FOB_London_Close_USD         63.829714
# Coal_RB_5700_FOB_London_Close_USD         78.299039
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD      84.102362
# Coal_India_5500_CFR_London_Close_USD      56.892333
# Price_WTI                                 20.546569
# Price_Brent_Oil                           20.675626
# Price_Dubai_Brent_Oil                     20.420990
# Price_ExxonMobil                          27.739038
# Price_Shenhua                              6.112206
# Price_All_Share                         7908.144823
# Price_Mining                            7008.696787
# Price_LNG_Japan_Korea_Marker_PLATTS       12.723932
# Price_ZAR_USD                              0.006038
# Price_Natural_Gas                          1.916904
# Price_ICE                                 13.645550
# Price_Dutch_TTF                           53.996066
# Price_Indian_en_exg_rate                  53.898404
# dtype: float64

# %% [markdown]
# **Variance  measures how spread out the values in a dataset are.**

# %%
variance=df["Coal_RB_4800_FOB_London_Close_USD"].var()          #Variance of second column
print(variance)
# Out:
# 2294.182105567026

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.15.2

# %% [markdown]
# **Skewness and Kurtosis are measures of how a data set is shaped.**

# %%
from scipy.stats import kurtosis, skew

# %%
skew(df["Coal_RB_4800_FOB_London_Close_USD"])
# Out:
# np.float64(1.350277201916089)

# %%
kurtosis(df["Coal_RB_4800_FOB_London_Close_USD"])
# Out:
# np.float64(2.2429796442861702)

# %%
skew(df["Coal_RB_5500_FOB_London_Close_USD"])
# Out:
# np.float64(1.2795194618629417)

# %%
df.std()
# Out:
# Coal_RB_4800_FOB_London_Close_USD         47.897621
# Coal_RB_5500_FOB_London_Close_USD         63.829714
# Coal_RB_5700_FOB_London_Close_USD         78.299039
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD      84.102362
# Coal_India_5500_CFR_London_Close_USD      56.892333
# Price_WTI                                 20.546569
# Price_Brent_Oil                           20.675626
# Price_Dubai_Brent_Oil                     20.420990
# Price_ExxonMobil                          27.739038
# Price_Shenhua                              6.112206
# Price_All_Share                         7908.144823
# Price_Mining                            7008.696787
# Price_LNG_Japan_Korea_Marker_PLATTS       12.723932
# Price_ZAR_USD                              0.006038
# Price_Natural_Gas                          1.916904
# Price_ICE                                 13.645550
# Price_Dutch_TTF                           53.996066
# Price_Indian_en_exg_rate                  53.898404
# dtype: float64

# %%
df2=df.iloc[0:,1:]
df2.var()
# Out:
# Coal_RB_5500_FOB_London_Close_USD       4.074232e+03
# Coal_RB_5700_FOB_London_Close_USD       6.130739e+03
# Coal_RB_6000_FOB_CurrentWeek_Avg_USD    7.073207e+03
# Coal_India_5500_CFR_London_Close_USD    3.236738e+03
# Price_WTI                               4.221615e+02
# Price_Brent_Oil                         4.274815e+02
# Price_Dubai_Brent_Oil                   4.170168e+02
# Price_ExxonMobil                        7.694542e+02
# Price_Shenhua                           3.735906e+01
# Price_All_Share                         6.253875e+07
# Price_Mining                            4.912183e+07
# Price_LNG_Japan_Korea_Marker_PLATTS     1.618984e+02
# Price_ZAR_USD                           3.645467e-05
# Price_Natural_Gas                       3.674520e+00
# Price_ICE                               1.862010e+02
# Price_Dutch_TTF                         2.915575e+03
# Price_Indian_en_exg_rate                2.905038e+03
# dtype: float64

# %% [markdown]
# **Cleaning by substituting the mean value to the null value**

# %%
df
# Out:
#       Coal_RB_4800_FOB_London_Close_USD  Coal_RB_5500_FOB_London_Close_USD  \
# 1                                 40.34                              52.36
# 3                                 40.34                              52.36
# 4                                 40.34                              52.36
# 5                                 33.82                              43.58
# 9                                 33.82                              43.58
# ...                                 ...                                ...
# 1102                              73.30                              94.56
# 1103                              73.30                              94.56
# 1104                              73.30                              94.56
# 1105                              73.30                              94.56
# 1106                              71.38                              92.08
#
# ...

# %%
df.fillna(df.mean(), inplace=True)  #for substituting the null values with mean of that column
df
# Out:
#       Coal_RB_4800_FOB_London_Close_USD  Coal_RB_5500_FOB_London_Close_USD  \
# 1                                 40.34                              52.36
# 3                                 40.34                              52.36
# 4                                 40.34                              52.36
# 5                                 33.82                              43.58
# 9                                 33.82                              43.58
# ...                                 ...                                ...
# 1102                              73.30                              94.56
# 1103                              73.30                              94.56
# 1104                              73.30                              94.56
# 1105                              73.30                              94.56
# 1106                              71.38                              92.08
#
# ...
